# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime
from itertools import chain

client = MongoClient("mongodb://localhost:27017/")
db = client["recommender_system"] 
collection = db["admissions_discharges"]

# %%
start_date = datetime(2024, 3, 1)
end_date = datetime(2024, 3, 31, 23, 59, 59)
query = {
    "date": {
        "$gte": start_date,
        "$lte": end_date
    }
}
cursor = collection.find(query)
df = pd.DataFrame(list(cursor))

# %%
df.shape
# Out:
# (31, 19)

# %%
diagnoses_icds = []
emergency_ids = []
other_ids = []
for i in range(len(df)): 
    emergency_ids.append(df.iloc[i]['hadm_ids_emergency'])
    other_ids.append(df.iloc[i]['hadm_ids_other'])

# %%
flattened = list(chain.from_iterable(emergency_ids))
unique_emergency_ids = list(set(flattened))
flattened = list(chain.from_iterable(other_ids))
unique_other_ids = list(set(flattened))

# %%
hadm_ids = []
hadm_ids.append(unique_emergency_ids)
hadm_ids.append(unique_other_ids) 
flattened = list(chain.from_iterable(hadm_ids)) 
unique_hadm_ids = list(set(flattened))

# %%
unique_hadm_ids
# Out:
# [25345025,
#  20444674,
#  21869570,
#  27535364,
#  29769736,
#  25863179,
#  25272331,
#  23909902,
#  26317840,
#  21137424,
#  29172242,
#  21223956,
#  22499348,
#  24395288,
#  23321627,
#  22107164,
#  29614622,
#  27380769,
#  29527588,
#  22161445,
#  24044584,
#  28335657,
#  25607722,
#  27433515,
#  20842540,
#  28022830,
#  23346223,
#  28267056,
#  27693106,
#  28853300,
#  27729462,
#  27012662,
#  23623224,
#  28247094,
#  26873913,
#  20329019,
#  26688057,
#  21154875,
#  28288574,
#  27309636,
#  20582983,
#  27682375,
#  28831305,
#  27383372,
#  24513106,
#  26311763,
#  21774933,
#  21664854,
#  29953111,
#  21534300,
#  25701469,
#  24825440,
#  28466275,
#  25229925,
#  20165734,
#  27217002,
#  26025579,
#  21646444,
#  29023853,
#  28037230,
#  24057964,
#  21422707,
#  22873205,
#  24463990,
#  22052982,
#  21750390,
#  20187769,
#  23110267,
#  27757692,
#  21915776,
#  28717697,
#  20434050,
#  27853440,
#  23052417,
#  20894341,
#  21214338,
#  29880455,
#  20976257,
#  24557197,
#  20700814,
#  23448206,
#  22279314,
#  23424661,
#  20926615,
#  26984601,
#  20636315,
#  27349660,
#  27484316,
#  27391643,
#  25287839,
#  29649567,
#  20943009,
#  22618786,
#  22482589,
#  28536996,
#  29588131,
#  28466851,
#  22278820,
#  28010662,
#  27727529,
#  27034794,
#  28648618,
#  25322154,
#  29371059,
#  25433782,
#  20037816,
#  25353403,
#  28246717,
#  22112960,
#  22239426,
#  23715523,
#  25688262,
#  20876999,
#  23764168,
#  22514378,
#  24579787,
#  24202445,
#  28809934,
#  23890638,
#  20296910,
#  24871124,
#  28954846,
#  24273118,
#  23652576,
#  23592671,
#  25332969,
#  22030571,
#  24604911,
#  24635121,
#  29511412,
#  27743989,
#  20424437,
#  27452152,
#  27138300,
#  22561021,
#  26436864,
#  22197506,
#  23406071,
#  23112965,
#  25362182,
#  28364553,
#  22234893,
#  29413133,
#  21841167,
#  24253199,
#  20120850,
#  28878610,
#  23931668,
#  22935318,
#  26919191,
#  24638232,
#  23841561,
#  23872282,
#  28422940,
#  28076318,
#  24636704,
#  28091169,
#  20276010,
#  24214314,
#  27778350,
#  26779439,
#  25996592,
#  22176054,
#  26732855,
#  23707965,
#  25761600,
#  24552769,
#  24673093,
#  26106181,
#  25863500,
#  27352910,
#  28108626,
#  25547604,
#  20248405,
#  23779668,
#  25269079,
#  26016088,
#  20347739,
#  28638045,
#  23020382,
#  22441310,
#  28208477,
#  26941790,
#  26693986,
#  20067171,
#  29044580,
#  21845861,
#  27813219,
#  22268778,
#  29223787,
#  28197740,
#  24336749,
#  29997422,
#  23941490,
#  29356404,
#  24615797,
#  26913654,
#  23980919,
#  29686645,
#  23940982,
#  29209975,
#  28245881,
#  27872638,
#  29754238,
#  24881025,
#  21399938,
#  29502339,
#  27436931,
#  20531077,
#  20587396,
#  26443656,
#  27837320,
#  26757515,
#  24607116,
#  26089869,
#  29697934,
#  20435341,
#  29174671,
#  23234448,
#  27873682,
#  29025679,
#  28222862,
#  25901456,
#  29025686,
#  24682384,
#  25350547,
#  26606485,
#  23081882,
#  21584795,
#  23828381,
#  20311454,
#  28539807,
#  22543263,
#  28324769,
#  28120996,
#  29209508,
#  23427492,
#  27404709,
#  25614756,
#  24583081,
#  23192490,
#  21402025,
#  21794732,
#  27085749,
#  26727350,
#  29866935,
#  29151159,
#  24028601,
#  21791676,
#  23739838,
#  25202623,
#  20715971,
#  25093061,
#  28197318,
#  23503815,
#  27289034,
#  21364683,
#  25630156,
#  20990411,
#  27288014,
#  26789834,
#  22527442,
#  28611028,
#  28954078,
#  24657887,
#  29375970,
#  26306534,
#  27948521,
#  21800938,
#  28533227,
#  29880300,
#  20955118,
#  27016174,
#  27183089,
#  27420146,
#  26478067,
#  22822900,
#  28281843,
#  20827125,
#  25578487,
#  21178874,
#  24283644,
#  27017213]

# %%
emergency_ids =  df.iloc[0]['hadm_ids_emergency']

# %%
for j in range(len(emergency_ids)):
    print(emergency_ids[j])
# Out:
# 28335657
# 27034794
# 28466275
# 23020382
# 20943009
# 29866935

# %%
db_MIMIC = client["MIMIC"] 
collection_diagnoses_icd = db_MIMIC["diagnoses_icd"]
collection_procedures_icd = db_MIMIC["procedures_icd"]
collection_admissions = db_MIMIC["admissions"]
collection_patients = db_MIMIC["patients"]

# %%
# diagnoses_icds = []
# procedures_icds = []
for hadm_id in unique_hadm_ids: 
    print(hadm_id)
    cursor = collection_diagnoses_icd.find({"hadm_id": hadm_id})
    documents = list(cursor)
    print('diagnoses_icd',len(documents))
    for doc in documents:
        doc.pop("_id", None)  
    collection = db["diagnoses_icd"] 
    if documents: 
        result = collection.insert_many(documents)
        print(f"{len(result.inserted_ids)} records inserted.")

    
    cursor = collection_procedures_icd.find({"hadm_id": hadm_id})
    documents = list(cursor)
    print('procedures_icd',len(documents))
    for doc in documents:
        doc.pop("_id", None)  
    collection = db["procedures_icd"] 
    if documents: 
        result = collection.insert_many(documents)
        print(f"{len(result.inserted_ids)} records inserted.")
# # Convert to DataFrame
# df_diagnoses = pd.DataFrame(diagnoses_icds)
# df_procedures = pd.DataFrame(procedures_icds)
# Out:
# 25345025
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20444674
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 21869570
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 6
# 6 records inserted.
# 27535364
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 29769736
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 25863179
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 2
# 2 records inserted.
# 25272331
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 23909902
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 26317840
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 21137424
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 5
# 5 records inserted.
# 29172242
# diagnoses_icd 39
# 39 records inserted.
# procedures_icd 19
# 19 records inserted.
# 21223956
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 22499348
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 2
# 2 records inserted.
# 24395288
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 23321627
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22107164
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29614622
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 0
# 27380769
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29527588
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 22161445
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 24044584
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28335657
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 25607722
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27433515
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 20842540
# diagnoses_icd 22
# 22 records inserted.
# procedures_icd 7
# 7 records inserted.
# 28022830
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 2
# 2 records inserted.
# 23346223
# diagnoses_icd 20
# 20 records inserted.
# procedures_icd 0
# 28267056
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 27693106
# diagnoses_icd 16
# 16 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28853300
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27729462
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27012662
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 23623224
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 28247094
# diagnoses_icd 39
# 39 records inserted.
# procedures_icd 21
# 21 records inserted.
# 26873913
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 4
# 4 records inserted.
# 20329019
# diagnoses_icd 25
# 25 records inserted.
# procedures_icd 11
# 11 records inserted.
# 26688057
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 3
# 3 records inserted.
# 21154875
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 3
# 3 records inserted.
# 28288574
# diagnoses_icd 30
# 30 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27309636
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 6
# 6 records inserted.
# 20582983
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 0
# 27682375
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28831305
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 27383372
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 3
# 3 records inserted.
# 24513106
# diagnoses_icd 1
# 1 records inserted.
# procedures_icd 0
# 26311763
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 21774933
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 21664854
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 29953111
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 21534300
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 25701469
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 24825440
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28466275
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 1
# 1 records inserted.
# 25229925
# diagnoses_icd 34
# 34 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20165734
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 27217002
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 3
# 3 records inserted.
# 26025579
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 21646444
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29023853
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 28037230
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 24057964
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 21422707
# diagnoses_icd 29
# 29 records inserted.
# procedures_icd 16
# 16 records inserted.
# 22873205
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 3
# 3 records inserted.
# 24463990
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 22052982
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 4
# 4 records inserted.
# 21750390
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 20187769
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 23110267
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27757692
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 0
# 21915776
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28717697
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 20434050
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 2
# 2 records inserted.
# 27853440
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 3
# 3 records inserted.
# 23052417
# diagnoses_icd 19
# 19 records inserted.
# procedures_icd 9
# 9 records inserted.
# 20894341
# diagnoses_icd 24
# 24 records inserted.
# procedures_icd 10
# 10 records inserted.
# 21214338
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29880455
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 20976257
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 0
# 24557197
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 20700814
# diagnoses_icd 39
# 39 records inserted.
# procedures_icd 3
# 3 records inserted.
# 23448206
# diagnoses_icd 19
# 19 records inserted.
# procedures_icd 5
# 5 records inserted.
# 22279314
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 8
# 8 records inserted.
# 23424661
# diagnoses_icd 19
# 19 records inserted.
# procedures_icd 6
# 6 records inserted.
# 20926615
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 26984601
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 20636315
# diagnoses_icd 25
# 25 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27349660
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27484316
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27391643
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 4
# 4 records inserted.
# 25287839
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29649567
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20943009
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 0
# 22618786
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22482589
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28536996
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 29588131
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28466851
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 2
# 2 records inserted.
# 22278820
# diagnoses_icd 21
# 21 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28010662
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27727529
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27034794
# diagnoses_icd 31
# 31 records inserted.
# procedures_icd 6
# 6 records inserted.
# 28648618
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 0
# 25322154
# diagnoses_icd 27
# 27 records inserted.
# procedures_icd 4
# 4 records inserted.
# 29371059
# diagnoses_icd 21
# 21 records inserted.
# procedures_icd 5
# 5 records inserted.
# 25433782
# diagnoses_icd 28
# 28 records inserted.
# procedures_icd 0
# 20037816
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 25353403
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28246717
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22112960
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 22239426
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 3
# 3 records inserted.
# 23715523
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 25688262
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 2
# 2 records inserted.
# 20876999
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 23764168
# diagnoses_icd 16
# 16 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22514378
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 1
# 1 records inserted.
# 24579787
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 4
# 4 records inserted.
# 24202445
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 28809934
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 0
# 23890638
# diagnoses_icd 29
# 29 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20296910
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 2
# 2 records inserted.
# 24871124
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28954846
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 24273118
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 2
# 2 records inserted.
# 23652576
# diagnoses_icd 1
# 1 records inserted.
# procedures_icd 0
# 23592671
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 3
# 3 records inserted.
# 25332969
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 5
# 5 records inserted.
# 22030571
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 3
# 3 records inserted.
# 24604911
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 4
# 4 records inserted.
# 24635121
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 29511412
# diagnoses_icd 38
# 38 records inserted.
# procedures_icd 8
# 8 records inserted.
# 27743989
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 20424437
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27452152
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27138300
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22561021
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 2
# 2 records inserted.
# 26436864
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 2
# 2 records inserted.
# 22197506
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 23406071
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 2
# 2 records inserted.
# 23112965
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 25362182
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 4
# 4 records inserted.
# 28364553
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 22234893
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 29413133
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 3
# 3 records inserted.
# 21841167
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 3
# 3 records inserted.
# 24253199
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 3
# 3 records inserted.
# 20120850
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 6
# 6 records inserted.
# 28878610
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 23931668
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 4
# 4 records inserted.
# 22935318
# diagnoses_icd 20
# 20 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26919191
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 24638232
# diagnoses_icd 28
# 28 records inserted.
# procedures_icd 7
# 7 records inserted.
# 23841561
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 2
# 2 records inserted.
# 23872282
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28422940
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 5
# 5 records inserted.
# 28076318
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 24636704
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 28091169
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 20276010
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 24214314
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27778350
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26779439
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 5
# 5 records inserted.
# 25996592
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22176054
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26732855
# diagnoses_icd 27
# 27 records inserted.
# procedures_icd 4
# 4 records inserted.
# 23707965
# diagnoses_icd 22
# 22 records inserted.
# procedures_icd 1
# 1 records inserted.
# 25761600
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 5
# 5 records inserted.
# 24552769
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 1
# 1 records inserted.
# 24673093
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 6
# 6 records inserted.
# 26106181
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 6
# 6 records inserted.
# 25863500
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 3
# 3 records inserted.
# 27352910
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 28108626
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 0
# 25547604
# diagnoses_icd 20
# 20 records inserted.
# procedures_icd 0
# 20248405
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 23779668
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 2
# 2 records inserted.
# 25269079
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26016088
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 0
# 20347739
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 0
# 28638045
# diagnoses_icd 25
# 25 records inserted.
# procedures_icd 4
# 4 records inserted.
# 23020382
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 22441310
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 28208477
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26941790
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26693986
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 20067171
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29044580
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 2
# 2 records inserted.
# 21845861
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 5
# 5 records inserted.
# 27813219
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 2
# 2 records inserted.
# 22268778
# diagnoses_icd 22
# 22 records inserted.
# procedures_icd 0
# 29223787
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 28197740
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 24336749
# diagnoses_icd 16
# 16 records inserted.
# procedures_icd 0
# 29997422
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 5
# 5 records inserted.
# 23941490
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 29356404
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 0
# 24615797
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 2
# 2 records inserted.
# 26913654
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 23980919
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 0
# 29686645
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 4
# 4 records inserted.
# 23940982
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 5
# 5 records inserted.
# 29209975
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 0
# 28245881
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 0
# 27872638
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 2
# 2 records inserted.
# 29754238
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 24881025
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 21399938
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29502339
# diagnoses_icd 26
# 26 records inserted.
# procedures_icd 0
# 27436931
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 20531077
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 20587396
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26443656
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27837320
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26757515
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 3
# 3 records inserted.
# 24607116
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 2
# 2 records inserted.
# 26089869
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 29697934
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 0
# 20435341
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 6
# 6 records inserted.
# 29174671
# diagnoses_icd 24
# 24 records inserted.
# procedures_icd 0
# 23234448
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 2
# 2 records inserted.
# 27873682
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29025679
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 28222862
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 1
# 1 records inserted.
# 25901456
# diagnoses_icd 18
# 18 records inserted.
# procedures_icd 0
# 29025686
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 4
# 4 records inserted.
# 24682384
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 25350547
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 26606485
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 4
# 4 records inserted.
# 23081882
# diagnoses_icd 32
# 32 records inserted.
# procedures_icd 2
# 2 records inserted.
# 21584795
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 2
# 2 records inserted.
# 23828381
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 3
# 3 records inserted.
# 20311454
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 28539807
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 0
# 22543263
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 28324769
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 28120996
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29209508
# diagnoses_icd 14
# 14 records inserted.
# procedures_icd 1
# 1 records inserted.
# 23427492
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 2
# 2 records inserted.
# 27404709
# diagnoses_icd 28
# 28 records inserted.
# procedures_icd 3
# 3 records inserted.
# 25614756
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 0
# 24583081
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 23192490
# diagnoses_icd 3
# 3 records inserted.
# procedures_icd 0
# 21402025
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 21794732
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 1
# 1 records inserted.
# 27085749
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 26727350
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29866935
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 1
# 1 records inserted.
# 29151159
# diagnoses_icd 11
# 11 records inserted.
# procedures_icd 0
# 24028601
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 21791676
# diagnoses_icd 16
# 16 records inserted.
# procedures_icd 5
# 5 records inserted.
# 23739838
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 1
# 1 records inserted.
# 25202623
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20715971
# diagnoses_icd 2
# 2 records inserted.
# procedures_icd 0
# 25093061
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 6
# 6 records inserted.
# 28197318
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 23503815
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 27289034
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 2
# 2 records inserted.
# 21364683
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 4
# 4 records inserted.
# 25630156
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 20990411
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 4
# 4 records inserted.
# 27288014
# diagnoses_icd 8
# 8 records inserted.
# procedures_icd 0
# 26789834
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 22527442
# diagnoses_icd 36
# 36 records inserted.
# procedures_icd 5
# 5 records inserted.
# 28611028
# diagnoses_icd 4
# 4 records inserted.
# procedures_icd 1
# 1 records inserted.
# 28954078
# diagnoses_icd 6
# 6 records inserted.
# procedures_icd 0
# 24657887
# diagnoses_icd 22
# 22 records inserted.
# procedures_icd 6
# 6 records inserted.
# 29375970
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 26306534
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 0
# 27948521
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 0
# 21800938
# diagnoses_icd 9
# 9 records inserted.
# procedures_icd 2
# 2 records inserted.
# 28533227
# diagnoses_icd 1
# 1 records inserted.
# procedures_icd 0
# 29880300
# diagnoses_icd 16
# 16 records inserted.
# procedures_icd 0
# 20955118
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 27016174
# diagnoses_icd 7
# 7 records inserted.
# procedures_icd 0
# 27183089
# diagnoses_icd 13
# 13 records inserted.
# procedures_icd 11
# 11 records inserted.
# 27420146
# diagnoses_icd 23
# 23 records inserted.
# procedures_icd 0
# 26478067
# diagnoses_icd 10
# 10 records inserted.
# procedures_icd 1
# 1 records inserted.
# 22822900
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 3
# 3 records inserted.
# 28281843
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 1
# 1 records inserted.
# 20827125
# diagnoses_icd 15
# 15 records inserted.
# procedures_icd 6
# 6 records inserted.
# 25578487
# diagnoses_icd 17
# 17 records inserted.
# procedures_icd 0
# 21178874
# diagnoses_icd 12
# 12 records inserted.
# procedures_icd 0
# 24283644
# diagnoses_icd 5
# 5 records inserted.
# procedures_icd 0
# 27017213
# diagnoses_icd 22
# 22 records inserted.
# procedures_icd 2
# 2 records inserted.

# %%
24579787 in unique_hadm_ids
# Out:
# True

# %%
cursor = collection_diagnoses_icd.find({"hadm_id": 24579787})
documents = list(cursor)

# %%
admissions_cursor = collection_admissions.find({"hadm_id": {"$in": unique_hadm_ids}})
df_admissions = pd.DataFrame(list(admissions_cursor))

# %%
subject_ids = df_admissions['subject_id'].unique().tolist()

# %%
records = df_admissions.to_dict('records')  
# collection = db["admissions"]
if records: 
    collection.insert_many(records)

# %%
subject_ids
# Out:
# [10046543,
#  10188106,
#  10207914,
#  10247468,
#  10261732,
#  10270108,
#  10312052,
#  10342727,
#  10346869,
#  10396938,
#  10449873,
#  10467410,
#  10493420,
#  10529115,
#  10536786,
#  10540284,
#  10556566,
#  10570079,
#  10572666,
#  10592833,
#  10602678,
#  10624561,
#  10648095,
#  10649183,
#  10669823,
#  10674504,
#  10676442,
#  10706500,
#  10717970,
#  10745565,
#  10746247,
#  10751258,
#  10755791,
#  10787196,
#  10800472,
#  10844079,
#  10937510,
#  10958253,
#  11069955,
#  11113889,
#  11119871,
#  11122975,
#  11126859,
#  11127819,
#  11151861,
#  11168491,
#  11171757,
#  11230090,
#  11266795,
#  11300135,
#  11334817,
#  11415869,
#  11422670,
#  11451795,
#  11493762,
#  11520986,
#  11554694,
#  11581862,
#  11621470,
#  11708854,
#  11724731,
#  11750274,
#  11770961,
#  11786902,
#  11801099,
#  11818101,
#  11854989,
#  11871004,
#  11902324,
#  11945540,
#  11966397,
#  11992390,
#  12122921,
#  12124962,
#  12175862,
#  12209542,
#  12235568,
#  12271405,
#  12338292,
#  12344190,
#  12414946,
#  12428722,
#  12452729,
#  12474949,
#  12481952,
#  12547294,
#  12584804,
#  12606543,
#  12623657,
#  12631532,
#  12648612,
#  12682931,
#  12701907,
#  12743926,
#  12801556,
#  12803153,
#  12806972,
#  12824529,
#  12825337,
#  12870526,
#  12886548,
#  12929147,
#  13017137,
#  13018839,
#  13039405,
#  13040343,
#  13049401,
#  13128781,
#  13282789,
#  13297743,
#  13307767,
#  13321760,
#  13383248,
#  13471727,
#  13507232,
#  13528817,
#  13532356,
#  13557705,
#  13584937,
#  13614978,
#  13620446,
#  13640324,
#  13674486,
#  13717854,
#  13727534,
#  13743788,
#  13785400,
#  13805783,
#  13814807,
#  13846210,
#  13878681,
#  13885205,
#  13886221,
#  13917910,
#  13954367,
#  13994599,
#  14065514,
#  14112662,
#  14120635,
#  14121288,
#  14178540,
#  14253478,
#  14368105,
#  14388973,
#  14405318,
#  14457951,
#  14519121,
#  14568429,
#  14587328,
#  14599343,
#  14623180,
#  14624945,
#  14629406,
#  14677148,
#  14702995,
#  14718089,
#  14732249,
#  14800709,
#  14813021,
#  14813129,
#  14840089,
#  14881763,
#  14969719,
#  15060292,
#  15163056,
#  15183993,
#  15192243,
#  15228243,
#  15243644,
#  15287734,
#  15360771,
#  15400037,
#  15408578,
#  15467139,
#  15471505,
#  15497616,
#  15534262,
#  15590663,
#  15668092,
#  15682570,
#  15689104,
#  15702242,
#  15758627,
#  15784951,
#  15796056,
#  15935256,
#  15950302,
#  16106417,
#  16187076,
#  16427239,
#  16431438,
#  16435424,
#  16475189,
#  16527660,
#  16585004,
#  16591214,
#  16597218,
#  16647430,
#  16655585,
#  16707561,
#  16824728,
#  16828559,
#  16908814,
#  16929344,
#  16930714,
#  16938510,
#  16944689,
#  16983420,
#  17003201,
#  17020399,
#  17031405,
#  17079680,
#  17112109,
#  17157555,
#  17245945,
#  17309286,
#  17359380,
#  17439859,
#  17472354,
#  17483123,
#  17489585,
#  17512239,
#  17516272,
#  17536969,
#  17577231,
#  17588958,
#  17618022,
#  17765398,
#  17999883,
#  18009231,
#  18011384,
#  18133146,
#  18224048,
#  18264239,
#  18275312,
#  18339582,
#  18367623,
#  18371155,
#  18519417,
#  18528770,
#  18574721,
#  18664295,
#  18667723,
#  18708396,
#  18712944,
#  18715035,
#  18785642,
#  18790180,
#  18816555,
#  18845673,
#  18879099,
#  19073526,
#  19102334,
#  19368299,
#  19422002,
#  19451054,
#  19470526,
#  19562159,
#  19638442,
#  19672997,
#  19895627,
#  19936109]

# %%
patients_cursor = collection_patients.find({"subject_id": {"$in": subject_ids}})
df_patients = pd.DataFrame(list(patients_cursor))

# %%
df_patients
# Out:
#                           _id  subject_id gender  anchor_age  anchor_year  \
# 0    67c5655a24c857f62da20469    10046543      F          91         2155
# 1    67c5655a24c857f62da214d7    10188106      M          39         2151
# 2    67c5655a24c857f62da2173b    10207914      M          22         2155
# 3    67c5655a24c857f62da21bb4    10247468      M          23         2155
# 4    67c5655a24c857f62da21d70    10261732      F          79         2155
# ..                        ...         ...    ...         ...          ...
# 257  67c5656c24c857f62da65f01    19562159      F          81         2155
# 258  67c5656c24c857f62da667fa    19638442      F          47         2151
# 259  67c5656c24c857f62da66bdf    19672997      F          66         2155
# 260  67c5656c24c857f62da685ba    19895627      F          53         2154
# 261  67c5656c24c857f62da68a8a    19936109      F          80         2154
#
#     anchor_year_group        dod
# 0         2017 - 2019        NaT
# 1         2011 - 2013        NaT
# 2         2008 - 2010        NaT
# 3         2008 - 2010        NaT
# 4         2011 - 2013 2155-03-24
# ..                ...        ...
# 257       2017 - 2019        NaT
# 258       2008 - 2010        NaT
# 259       2011 - 2013 2155-05-02
# 260       2011 - 2013        NaT
# 261       2008 - 2010 2155-11-05
#
# [262 rows x 7 columns]

# %%
df_patients_cleaned = df_patients.where(pd.notnull(df_patients), None)
# Step 2: Convert timezone-aware datetime columns to naive datetime
for col in df_patients_cleaned.select_dtypes(include=["datetimetz"]).columns:
    df_patients_cleaned[col] = df_patients_cleaned[col].dt.tz_localize(None)

# Step 3: Convert to list of records
records = df_patients_cleaned.to_dict(orient='records')

# Step 4: Insert into MongoDB
collection = db["patients"]
if records:
    result = collection.insert_many(records)
    print(f"Inserted {len(result.inserted_ids)} records.")
else:
    print("No records to insert.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 12
#      10 collection = db["patients"]
#      11 if records:
# ---> 12     result = collection.insert_many(records)
#      13     print(f"Inserted {len(result.inserted_ids)} records.")
#      14 else:
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1896, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1882 """Execute an operation with consecutive retries if possible
#    1883
#    1884 Returns func()'s return value on success. On error retries the same
#    (...)
#    1893 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1894 """
#    1895 with self._tmp_session(session) as s:
# -> 1896     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1782, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1777 # Ensure that the options supports retry_writes and there is a valid session not in
#    1778 # transaction, otherwise, we will not support retry behavior for this txn.
#    1779 retryable = bool(
#    1780     retryable and self.options.retry_writes and session and not session.in_transaction
#    1781 )
# -> 1782 return self._retry_internal(
#    1783     func=func,
#    1784     session=session,
#    1785     bulk=bulk,
#    1786     operation=operation,
#    1787     retryable=retryable,
#    1788     operation_id=operation_id,
#    1789 )
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:2687, in _ClientConnectionRetryable._write(self)
#    2685             self._check_last_error()
#    2686             self._retryable = False
# -> 2687         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2688 except PyMongoError as exc:
#    2689     if not self._retryable:
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:461, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     453     result = bwc.conn.command(  # type: ignore[misc]
#     454         bwc.db_name,
#     455         batched_cmd,  # type: ignore[arg-type]
#    (...)
#     458         client=client,  # type: ignore[arg-type]
#     459     )
#     460 else:
# --> 461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
#     462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\message.py:699, in _BulkWriteContext.batch_command(self, cmd, docs)
#     695 def batch_command(
#     696     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]]
#     697 ) -> tuple[int, Union[bytes, dict[str, Any]], list[Mapping[str, Any]]]:
#     698     namespace = self.db_name + ".$cmd"
# --> 699     request_id, msg, to_send = _do_batched_op_msg(
#     700         namespace, self.op_type, cmd, docs, self.codec, self
#     701     )
#     702     if not to_send:
#     703         raise InvalidOperation("cannot do an empty bulk write")
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\message.py:926, in _do_batched_op_msg(namespace, operation, command, docs, opts, ctx)
#     924 if ctx.conn.compression_context:
#     925     return _batched_op_msg_compressed(operation, command, docs, ack, opts, ctx)
# --> 926 return _batched_op_msg(operation, command, docs, ack, opts, ctx)
#
# File nattype.pyx:54, in pandas._libs.tslibs.nattype._make_error_func.f()
#
# ValueError: NaTType does not support utcoffset

# %%
df_patients['dod'] = df_patients['dod'].apply(lambda x: x.to_pydatetime() if pd.notnull(x) else None)

# %%
df_patients['dod'] = df_patients['dod'].where(~df_patients['dod'].isna(), None)
# df_patients['dod'] = df_patients['dod'].replace(pd.NaT, None)

# %%
df_patients['dod'].where(df_patients['dod'].notna(), None)
# Out:
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4     2155-03-24
#          ...
# 257          NaT
# 258          NaT
# 259   2155-05-02
# 260          NaT
# 261   2155-11-05
# Name: dod, Length: 262, dtype: datetime64[ns]

# %%
df_patients.loc[:, 'dod'] = df_patients['dod'].where(df_patients['dod'].notna(), None)

# %%
df_patients.drop(columns=['dod'])
# Out:
#                           _id  subject_id gender  anchor_age  anchor_year  \
# 0    67c5655a24c857f62da20469    10046543      F          91         2155
# 1    67c5655a24c857f62da214d7    10188106      M          39         2151
# 2    67c5655a24c857f62da2173b    10207914      M          22         2155
# 3    67c5655a24c857f62da21bb4    10247468      M          23         2155
# 4    67c5655a24c857f62da21d70    10261732      F          79         2155
# ..                        ...         ...    ...         ...          ...
# 257  67c5656c24c857f62da65f01    19562159      F          81         2155
# 258  67c5656c24c857f62da667fa    19638442      F          47         2151
# 259  67c5656c24c857f62da66bdf    19672997      F          66         2155
# 260  67c5656c24c857f62da685ba    19895627      F          53         2154
# 261  67c5656c24c857f62da68a8a    19936109      F          80         2154
#
#     anchor_year_group
# 0         2017 - 2019
# 1         2011 - 2013
# 2         2008 - 2010
# 3         2008 - 2010
# 4         2011 - 2013
# ..                ...
# 257       2017 - 2019
# 258       2008 - 2010
# 259       2011 - 2013
# 260       2011 - 2013
# 261       2008 - 2010
#
# [262 rows x 6 columns]

# %%
records
# Out:
# [{'_id': ObjectId('67c5655a24c857f62da20469'),
#   'subject_id': 10046543,
#   'gender': 'F',
#   'anchor_age': 91,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da214d7'),
#   'subject_id': 10188106,
#   'gender': 'M',
#   'anchor_age': 39,
#   'anchor_year': 2151,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da2173b'),
#   'subject_id': 10207914,
#   'gender': 'M',
#   'anchor_age': 22,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da21bb4'),
#   'subject_id': 10247468,
#   'gender': 'M',
#   'anchor_age': 23,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da21d70'),
#   'subject_id': 10261732,
#   'gender': 'F',
#   'anchor_age': 79,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-03-24 00:00:00')},
#  {'_id': ObjectId('67c5655a24c857f62da21e6f'),
#   'subject_id': 10270108,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da2236e'),
#   'subject_id': 10312052,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-07-16 00:00:00')},
#  {'_id': ObjectId('67c5655a24c857f62da22717'),
#   'subject_id': 10342727,
#   'gender': 'F',
#   'anchor_age': 60,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da2279c'),
#   'subject_id': 10346869,
#   'gender': 'F',
#   'anchor_age': 32,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da22d60'),
#   'subject_id': 10396938,
#   'gender': 'F',
#   'anchor_age': 47,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da23395'),
#   'subject_id': 10449873,
#   'gender': 'F',
#   'anchor_age': 91,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da2356f'),
#   'subject_id': 10467410,
#   'gender': 'M',
#   'anchor_age': 64,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da2385d'),
#   'subject_id': 10493420,
#   'gender': 'F',
#   'anchor_age': 70,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da23ca5'),
#   'subject_id': 10529115,
#   'gender': 'F',
#   'anchor_age': 75,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da23d91'),
#   'subject_id': 10536786,
#   'gender': 'F',
#   'anchor_age': 84,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da23df0'),
#   'subject_id': 10540284,
#   'gender': 'M',
#   'anchor_age': 56,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da23fbf'),
#   'subject_id': 10556566,
#   'gender': 'F',
#   'anchor_age': 56,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655a24c857f62da24156'),
#   'subject_id': 10570079,
#   'gender': 'M',
#   'anchor_age': 21,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da2419a'),
#   'subject_id': 10572666,
#   'gender': 'M',
#   'anchor_age': 51,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da2442e'),
#   'subject_id': 10592833,
#   'gender': 'F',
#   'anchor_age': 68,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da24552'),
#   'subject_id': 10602678,
#   'gender': 'M',
#   'anchor_age': 39,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da247dd'),
#   'subject_id': 10624561,
#   'gender': 'M',
#   'anchor_age': 47,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da24a7d'),
#   'subject_id': 10648095,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da24aa8'),
#   'subject_id': 10649183,
#   'gender': 'F',
#   'anchor_age': 81,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da24d2a'),
#   'subject_id': 10669823,
#   'gender': 'F',
#   'anchor_age': 72,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2161-04-12 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da24dbf'),
#   'subject_id': 10674504,
#   'gender': 'F',
#   'anchor_age': 82,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-03-31 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da24dfb'),
#   'subject_id': 10676442,
#   'gender': 'F',
#   'anchor_age': 89,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-03-23 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da251bc'),
#   'subject_id': 10706500,
#   'gender': 'F',
#   'anchor_age': 41,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da25309'),
#   'subject_id': 10717970,
#   'gender': 'M',
#   'anchor_age': 77,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2156-07-23 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da2562a'),
#   'subject_id': 10745565,
#   'gender': 'F',
#   'anchor_age': 56,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da25642'),
#   'subject_id': 10746247,
#   'gender': 'M',
#   'anchor_age': 43,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da256d9'),
#   'subject_id': 10751258,
#   'gender': 'F',
#   'anchor_age': 32,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da25756'),
#   'subject_id': 10755791,
#   'gender': 'F',
#   'anchor_age': 82,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-03-09 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da25ae9'),
#   'subject_id': 10787196,
#   'gender': 'M',
#   'anchor_age': 47,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da25c6c'),
#   'subject_id': 10800472,
#   'gender': 'M',
#   'anchor_age': 39,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da26197'),
#   'subject_id': 10844079,
#   'gender': 'F',
#   'anchor_age': 75,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da26c5c'),
#   'subject_id': 10937510,
#   'gender': 'F',
#   'anchor_age': 30,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da26ece'),
#   'subject_id': 10958253,
#   'gender': 'M',
#   'anchor_age': 50,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da27b96'),
#   'subject_id': 11069955,
#   'gender': 'F',
#   'anchor_age': 70,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da280d4'),
#   'subject_id': 11113889,
#   'gender': 'M',
#   'anchor_age': 85,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-12-18 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da2819b'),
#   'subject_id': 11119871,
#   'gender': 'M',
#   'anchor_age': 76,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-05-21 00:00:00')},
#  {'_id': ObjectId('67c5655b24c857f62da28206'),
#   'subject_id': 11122975,
#   'gender': 'F',
#   'anchor_age': 85,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da2827a'),
#   'subject_id': 11126859,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655b24c857f62da28290'),
#   'subject_id': 11127819,
#   'gender': 'M',
#   'anchor_age': 61,
#   'anchor_year': 2151,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-05-24 00:00:00')},
#  {'_id': ObjectId('67c5655c24c857f62da28589'),
#   'subject_id': 11151861,
#   'gender': 'F',
#   'anchor_age': 67,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da28785'),
#   'subject_id': 11168491,
#   'gender': 'M',
#   'anchor_age': 60,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da287f6'),
#   'subject_id': 11171757,
#   'gender': 'F',
#   'anchor_age': 91,
#   'anchor_year': 2150,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da28eb9'),
#   'subject_id': 11230090,
#   'gender': 'F',
#   'anchor_age': 24,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da29303'),
#   'subject_id': 11266795,
#   'gender': 'F',
#   'anchor_age': 26,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da296e3'),
#   'subject_id': 11300135,
#   'gender': 'F',
#   'anchor_age': 60,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da29aca'),
#   'subject_id': 11334817,
#   'gender': 'M',
#   'anchor_age': 60,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-08-10 00:00:00')},
#  {'_id': ObjectId('67c5655c24c857f62da2a40d'),
#   'subject_id': 11415869,
#   'gender': 'M',
#   'anchor_age': 54,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2a4d5'),
#   'subject_id': 11422670,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2a82d'),
#   'subject_id': 11451795,
#   'gender': 'F',
#   'anchor_age': 64,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2acdc'),
#   'subject_id': 11493762,
#   'gender': 'F',
#   'anchor_age': 28,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2aff6'),
#   'subject_id': 11520986,
#   'gender': 'F',
#   'anchor_age': 53,
#   'anchor_year': 2148,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2b407'),
#   'subject_id': 11554694,
#   'gender': 'M',
#   'anchor_age': 80,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-09-06 00:00:00')},
#  {'_id': ObjectId('67c5655c24c857f62da2b73b'),
#   'subject_id': 11581862,
#   'gender': 'M',
#   'anchor_age': 63,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655c24c857f62da2bbec'),
#   'subject_id': 11621470,
#   'gender': 'F',
#   'anchor_age': 33,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2c60c'),
#   'subject_id': 11708854,
#   'gender': 'F',
#   'anchor_age': 59,
#   'anchor_year': 2149,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2156-03-30 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2c7dc'),
#   'subject_id': 11724731,
#   'gender': 'M',
#   'anchor_age': 86,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2cafb'),
#   'subject_id': 11750274,
#   'gender': 'F',
#   'anchor_age': 76,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2cd6f'),
#   'subject_id': 11770961,
#   'gender': 'F',
#   'anchor_age': 73,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2cf38'),
#   'subject_id': 11786902,
#   'gender': 'F',
#   'anchor_age': 76,
#   'anchor_year': 2151,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2157-03-20 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2d0d8'),
#   'subject_id': 11801099,
#   'gender': 'M',
#   'anchor_age': 36,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2d2bf'),
#   'subject_id': 11818101,
#   'gender': 'M',
#   'anchor_age': 44,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2d71e'),
#   'subject_id': 11854989,
#   'gender': 'F',
#   'anchor_age': 22,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2d914'),
#   'subject_id': 11871004,
#   'gender': 'F',
#   'anchor_age': 67,
#   'anchor_year': 2147,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2dcdd'),
#   'subject_id': 11902324,
#   'gender': 'M',
#   'anchor_age': 19,
#   'anchor_year': 2150,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655d24c857f62da2e1d9'),
#   'subject_id': 11945540,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2153,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2156-03-01 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2e44b'),
#   'subject_id': 11966397,
#   'gender': 'M',
#   'anchor_age': 68,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-12-08 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2e762'),
#   'subject_id': 11992390,
#   'gender': 'F',
#   'anchor_age': 29,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-03-30 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2f673'),
#   'subject_id': 12122921,
#   'gender': 'M',
#   'anchor_age': 80,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-08-20 00:00:00')},
#  {'_id': ObjectId('67c5655d24c857f62da2f6ad'),
#   'subject_id': 12124962,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da2fc8c'),
#   'subject_id': 12175862,
#   'gender': 'F',
#   'anchor_age': 68,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da30059'),
#   'subject_id': 12209542,
#   'gender': 'F',
#   'anchor_age': 27,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da30354'),
#   'subject_id': 12235568,
#   'gender': 'M',
#   'anchor_age': 91,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-04-06 00:00:00')},
#  {'_id': ObjectId('67c5655e24c857f62da307bf'),
#   'subject_id': 12271405,
#   'gender': 'M',
#   'anchor_age': 72,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2162-04-02 00:00:00')},
#  {'_id': ObjectId('67c5655e24c857f62da30fbf'),
#   'subject_id': 12338292,
#   'gender': 'F',
#   'anchor_age': 23,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da31073'),
#   'subject_id': 12344190,
#   'gender': 'M',
#   'anchor_age': 76,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da318da'),
#   'subject_id': 12414946,
#   'gender': 'F',
#   'anchor_age': 84,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da31a88'),
#   'subject_id': 12428722,
#   'gender': 'M',
#   'anchor_age': 61,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da31d79'),
#   'subject_id': 12452729,
#   'gender': 'M',
#   'anchor_age': 43,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da32010'),
#   'subject_id': 12474949,
#   'gender': 'F',
#   'anchor_age': 29,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655e24c857f62da320ee'),
#   'subject_id': 12481952,
#   'gender': 'M',
#   'anchor_age': 46,
#   'anchor_year': 2145,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-05-02 00:00:00')},
#  {'_id': ObjectId('67c5655e24c857f62da328b2'),
#   'subject_id': 12547294,
#   'gender': 'F',
#   'anchor_age': 22,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da32d18'),
#   'subject_id': 12584804,
#   'gender': 'M',
#   'anchor_age': 80,
#   'anchor_year': 2152,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da32f9c'),
#   'subject_id': 12606543,
#   'gender': 'F',
#   'anchor_age': 57,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33193'),
#   'subject_id': 12623657,
#   'gender': 'M',
#   'anchor_age': 38,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33263'),
#   'subject_id': 12631532,
#   'gender': 'F',
#   'anchor_age': 69,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33465'),
#   'subject_id': 12648612,
#   'gender': 'F',
#   'anchor_age': 37,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33863'),
#   'subject_id': 12682931,
#   'gender': 'F',
#   'anchor_age': 37,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33ab4'),
#   'subject_id': 12701907,
#   'gender': 'M',
#   'anchor_age': 20,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da33fa3'),
#   'subject_id': 12743926,
#   'gender': 'M',
#   'anchor_age': 67,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2156-07-17 00:00:00')},
#  {'_id': ObjectId('67c5655f24c857f62da34690'),
#   'subject_id': 12801556,
#   'gender': 'F',
#   'anchor_age': 24,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da346c5'),
#   'subject_id': 12803153,
#   'gender': 'F',
#   'anchor_age': 24,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da3472a'),
#   'subject_id': 12806972,
#   'gender': 'M',
#   'anchor_age': 23,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da3492d'),
#   'subject_id': 12824529,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2151,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da34943'),
#   'subject_id': 12825337,
#   'gender': 'M',
#   'anchor_age': 58,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da34e5e'),
#   'subject_id': 12870526,
#   'gender': 'F',
#   'anchor_age': 86,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-04-03 00:00:00')},
#  {'_id': ObjectId('67c5655f24c857f62da3503b'),
#   'subject_id': 12886548,
#   'gender': 'F',
#   'anchor_age': 28,
#   'anchor_year': 2147,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da35522'),
#   'subject_id': 12929147,
#   'gender': 'M',
#   'anchor_age': 60,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da35f6a'),
#   'subject_id': 13017137,
#   'gender': 'F',
#   'anchor_age': 84,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-03-23 00:00:00')},
#  {'_id': ObjectId('67c5655f24c857f62da35fa1'),
#   'subject_id': 13018839,
#   'gender': 'F',
#   'anchor_age': 35,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5655f24c857f62da36228'),
#   'subject_id': 13039405,
#   'gender': 'F',
#   'anchor_age': 60,
#   'anchor_year': 2153,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2155-05-21 00:00:00')},
#  {'_id': ObjectId('67c5655f24c857f62da36243'),
#   'subject_id': 13040343,
#   'gender': 'M',
#   'anchor_age': 49,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2160-10-30 00:00:00')},
#  {'_id': ObjectId('67c5655f24c857f62da3635f'),
#   'subject_id': 13049401,
#   'gender': 'F',
#   'anchor_age': 20,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da36c5e'),
#   'subject_id': 13128781,
#   'gender': 'M',
#   'anchor_age': 68,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da37e34'),
#   'subject_id': 13282789,
#   'gender': 'F',
#   'anchor_age': 70,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da37fea'),
#   'subject_id': 13297743,
#   'gender': 'F',
#   'anchor_age': 40,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2157-09-17 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da38115'),
#   'subject_id': 13307767,
#   'gender': 'F',
#   'anchor_age': 67,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da382c1'),
#   'subject_id': 13321760,
#   'gender': 'F',
#   'anchor_age': 81,
#   'anchor_year': 2149,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2156-03-31 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da389e8'),
#   'subject_id': 13383248,
#   'gender': 'M',
#   'anchor_age': 91,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-03-27 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da39411'),
#   'subject_id': 13471727,
#   'gender': 'F',
#   'anchor_age': 41,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da3981f'),
#   'subject_id': 13507232,
#   'gender': 'M',
#   'anchor_age': 47,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-09-03 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da39add'),
#   'subject_id': 13528817,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da39b36'),
#   'subject_id': 13532356,
#   'gender': 'M',
#   'anchor_age': 70,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-03-26 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da39dfe'),
#   'subject_id': 13557705,
#   'gender': 'F',
#   'anchor_age': 91,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da3a101'),
#   'subject_id': 13584937,
#   'gender': 'M',
#   'anchor_age': 70,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656024c857f62da3a4b7'),
#   'subject_id': 13614978,
#   'gender': 'F',
#   'anchor_age': 74,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2163-12-25 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da3a547'),
#   'subject_id': 13620446,
#   'gender': 'F',
#   'anchor_age': 58,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2163-08-02 00:00:00')},
#  {'_id': ObjectId('67c5656024c857f62da3a780'),
#   'subject_id': 13640324,
#   'gender': 'F',
#   'anchor_age': 80,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-04-03 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3ab55'),
#   'subject_id': 13674486,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3b070'),
#   'subject_id': 13717854,
#   'gender': 'M',
#   'anchor_age': 67,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2162-05-25 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3b1a3'),
#   'subject_id': 13727534,
#   'gender': 'F',
#   'anchor_age': 63,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3b382'),
#   'subject_id': 13743788,
#   'gender': 'M',
#   'anchor_age': 83,
#   'anchor_year': 2153,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3b858'),
#   'subject_id': 13785400,
#   'gender': 'M',
#   'anchor_age': 28,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3bad9'),
#   'subject_id': 13805783,
#   'gender': 'F',
#   'anchor_age': 19,
#   'anchor_year': 2152,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3bbf3'),
#   'subject_id': 13814807,
#   'gender': 'F',
#   'anchor_age': 88,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-06-24 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3bfb4'),
#   'subject_id': 13846210,
#   'gender': 'F',
#   'anchor_age': 70,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-04-04 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3c399'),
#   'subject_id': 13878681,
#   'gender': 'M',
#   'anchor_age': 82,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2156-09-16 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3c448'),
#   'subject_id': 13885205,
#   'gender': 'F',
#   'anchor_age': 49,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3c46b'),
#   'subject_id': 13886221,
#   'gender': 'F',
#   'anchor_age': 34,
#   'anchor_year': 2144,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3c7ed'),
#   'subject_id': 13917910,
#   'gender': 'M',
#   'anchor_age': 49,
#   'anchor_year': 2153,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3cbfe'),
#   'subject_id': 13954367,
#   'gender': 'F',
#   'anchor_age': 84,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3d0dc'),
#   'subject_id': 13994599,
#   'gender': 'F',
#   'anchor_age': 30,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3d968'),
#   'subject_id': 14065514,
#   'gender': 'M',
#   'anchor_age': 49,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3dec3'),
#   'subject_id': 14112662,
#   'gender': 'M',
#   'anchor_age': 66,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3dfbc'),
#   'subject_id': 14120635,
#   'gender': 'M',
#   'anchor_age': 57,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2157-03-15 00:00:00')},
#  {'_id': ObjectId('67c5656124c857f62da3dfce'),
#   'subject_id': 14121288,
#   'gender': 'M',
#   'anchor_age': 23,
#   'anchor_year': 2153,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656124c857f62da3e68a'),
#   'subject_id': 14178540,
#   'gender': 'M',
#   'anchor_age': 35,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da3efa3'),
#   'subject_id': 14253478,
#   'gender': 'F',
#   'anchor_age': 35,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da3fd64'),
#   'subject_id': 14368105,
#   'gender': 'M',
#   'anchor_age': 18,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da40001'),
#   'subject_id': 14388973,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da401e2'),
#   'subject_id': 14405318,
#   'gender': 'F',
#   'anchor_age': 50,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2155-05-10 00:00:00')},
#  {'_id': ObjectId('67c5656224c857f62da40812'),
#   'subject_id': 14457951,
#   'gender': 'M',
#   'anchor_age': 52,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da40f28'),
#   'subject_id': 14519121,
#   'gender': 'F',
#   'anchor_age': 40,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da414b3'),
#   'subject_id': 14568429,
#   'gender': 'M',
#   'anchor_age': 63,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-04-15 00:00:00')},
#  {'_id': ObjectId('67c5656224c857f62da416d8'),
#   'subject_id': 14587328,
#   'gender': 'F',
#   'anchor_age': 52,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da4184b'),
#   'subject_id': 14599343,
#   'gender': 'F',
#   'anchor_age': 66,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da41b2b'),
#   'subject_id': 14623180,
#   'gender': 'M',
#   'anchor_age': 56,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da41b57'),
#   'subject_id': 14624945,
#   'gender': 'F',
#   'anchor_age': 53,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da41bd3'),
#   'subject_id': 14629406,
#   'gender': 'F',
#   'anchor_age': 36,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da42178'),
#   'subject_id': 14677148,
#   'gender': 'F',
#   'anchor_age': 59,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656224c857f62da424aa'),
#   'subject_id': 14702995,
#   'gender': 'F',
#   'anchor_age': 81,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2163-03-09 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da42655'),
#   'subject_id': 14718089,
#   'gender': 'F',
#   'anchor_age': 25,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da427f7'),
#   'subject_id': 14732249,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2162-12-12 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da42ff4'),
#   'subject_id': 14800709,
#   'gender': 'F',
#   'anchor_age': 82,
#   'anchor_year': 2152,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da43160'),
#   'subject_id': 14813021,
#   'gender': 'F',
#   'anchor_age': 61,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da43162'),
#   'subject_id': 14813129,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da43490'),
#   'subject_id': 14840089,
#   'gender': 'M',
#   'anchor_age': 59,
#   'anchor_year': 2151,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da4397d'),
#   'subject_id': 14881763,
#   'gender': 'M',
#   'anchor_age': 69,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2155-03-03 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da443b2'),
#   'subject_id': 14969719,
#   'gender': 'F',
#   'anchor_age': 59,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2157-04-17 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da44e4b'),
#   'subject_id': 15060292,
#   'gender': 'M',
#   'anchor_age': 32,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da45a5d'),
#   'subject_id': 15163056,
#   'gender': 'M',
#   'anchor_age': 59,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da45ce9'),
#   'subject_id': 15183993,
#   'gender': 'F',
#   'anchor_age': 74,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656324c857f62da45de1'),
#   'subject_id': 15192243,
#   'gender': 'M',
#   'anchor_age': 69,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-03-26 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da46229'),
#   'subject_id': 15228243,
#   'gender': 'M',
#   'anchor_age': 77,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2160-10-16 00:00:00')},
#  {'_id': ObjectId('67c5656324c857f62da463f4'),
#   'subject_id': 15243644,
#   'gender': 'F',
#   'anchor_age': 25,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da46935'),
#   'subject_id': 15287734,
#   'gender': 'F',
#   'anchor_age': 50,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da471a9'),
#   'subject_id': 15360771,
#   'gender': 'M',
#   'anchor_age': 72,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da47653'),
#   'subject_id': 15400037,
#   'gender': 'M',
#   'anchor_age': 45,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da4774b'),
#   'subject_id': 15408578,
#   'gender': 'M',
#   'anchor_age': 29,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2159-09-11 00:00:00')},
#  {'_id': ObjectId('67c5656424c857f62da47e14'),
#   'subject_id': 15467139,
#   'gender': 'M',
#   'anchor_age': 83,
#   'anchor_year': 2150,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da47e79'),
#   'subject_id': 15471505,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da48175'),
#   'subject_id': 15497616,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2158-08-01 00:00:00')},
#  {'_id': ObjectId('67c5656424c857f62da485d1'),
#   'subject_id': 15534262,
#   'gender': 'F',
#   'anchor_age': 72,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-11-08 00:00:00')},
#  {'_id': ObjectId('67c5656424c857f62da48c95'),
#   'subject_id': 15590663,
#   'gender': 'F',
#   'anchor_age': 91,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2156-11-30 00:00:00')},
#  {'_id': ObjectId('67c5656424c857f62da495ef'),
#   'subject_id': 15668092,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da497c4'),
#   'subject_id': 15682570,
#   'gender': 'M',
#   'anchor_age': 71,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da4987e'),
#   'subject_id': 15689104,
#   'gender': 'F',
#   'anchor_age': 64,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656424c857f62da49a1b'),
#   'subject_id': 15702242,
#   'gender': 'F',
#   'anchor_age': 72,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4a083'),
#   'subject_id': 15758627,
#   'gender': 'M',
#   'anchor_age': 44,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4a3c4'),
#   'subject_id': 15784951,
#   'gender': 'F',
#   'anchor_age': 27,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4a522'),
#   'subject_id': 15796056,
#   'gender': 'F',
#   'anchor_age': 57,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2155-03-15 00:00:00')},
#  {'_id': ObjectId('67c5656524c857f62da4b4ff'),
#   'subject_id': 15935256,
#   'gender': 'M',
#   'anchor_age': 76,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4b6cc'),
#   'subject_id': 15950302,
#   'gender': 'F',
#   'anchor_age': 74,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4c91d'),
#   'subject_id': 16106417,
#   'gender': 'F',
#   'anchor_age': 34,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656524c857f62da4d268'),
#   'subject_id': 16187076,
#   'gender': 'M',
#   'anchor_age': 81,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da4eec7'),
#   'subject_id': 16427239,
#   'gender': 'M',
#   'anchor_age': 70,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-05-25 00:00:00')},
#  {'_id': ObjectId('67c5656624c857f62da4ef3f'),
#   'subject_id': 16431438,
#   'gender': 'M',
#   'anchor_age': 52,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da4efb7'),
#   'subject_id': 16435424,
#   'gender': 'F',
#   'anchor_age': 67,
#   'anchor_year': 2153,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da4f44a'),
#   'subject_id': 16475189,
#   'gender': 'F',
#   'anchor_age': 28,
#   'anchor_year': 2151,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da4fa78'),
#   'subject_id': 16527660,
#   'gender': 'M',
#   'anchor_age': 54,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da50118'),
#   'subject_id': 16585004,
#   'gender': 'M',
#   'anchor_age': 41,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da501c8'),
#   'subject_id': 16591214,
#   'gender': 'F',
#   'anchor_age': 33,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da50282'),
#   'subject_id': 16597218,
#   'gender': 'M',
#   'anchor_age': 24,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da50874'),
#   'subject_id': 16647430,
#   'gender': 'M',
#   'anchor_age': 28,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da5096c'),
#   'subject_id': 16655585,
#   'gender': 'M',
#   'anchor_age': 42,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656624c857f62da50f7c'),
#   'subject_id': 16707561,
#   'gender': 'M',
#   'anchor_age': 59,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da51d4f'),
#   'subject_id': 16824728,
#   'gender': 'F',
#   'anchor_age': 29,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da51dc7'),
#   'subject_id': 16828559,
#   'gender': 'M',
#   'anchor_age': 69,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da52723'),
#   'subject_id': 16908814,
#   'gender': 'F',
#   'anchor_age': 31,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da5298f'),
#   'subject_id': 16929344,
#   'gender': 'F',
#   'anchor_age': 63,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da529ad'),
#   'subject_id': 16930714,
#   'gender': 'M',
#   'anchor_age': 86,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2156-03-24 00:00:00')},
#  {'_id': ObjectId('67c5656724c857f62da52aaf'),
#   'subject_id': 16938510,
#   'gender': 'M',
#   'anchor_age': 34,
#   'anchor_year': 2152,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2155-10-15 00:00:00')},
#  {'_id': ObjectId('67c5656724c857f62da52b65'),
#   'subject_id': 16944689,
#   'gender': 'F',
#   'anchor_age': 61,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2156-10-07 00:00:00')},
#  {'_id': ObjectId('67c5656724c857f62da5301a'),
#   'subject_id': 16983420,
#   'gender': 'M',
#   'anchor_age': 68,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da53256'),
#   'subject_id': 17003201,
#   'gender': 'M',
#   'anchor_age': 23,
#   'anchor_year': 2154,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da53455'),
#   'subject_id': 17020399,
#   'gender': 'F',
#   'anchor_age': 53,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da535a7'),
#   'subject_id': 17031405,
#   'gender': 'M',
#   'anchor_age': 45,
#   'anchor_year': 2144,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da53b71'),
#   'subject_id': 17079680,
#   'gender': 'F',
#   'anchor_age': 46,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da53f32'),
#   'subject_id': 17112109,
#   'gender': 'F',
#   'anchor_age': 82,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da5442e'),
#   'subject_id': 17157555,
#   'gender': 'F',
#   'anchor_age': 58,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da54eb4'),
#   'subject_id': 17245945,
#   'gender': 'M',
#   'anchor_age': 84,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656724c857f62da5561f'),
#   'subject_id': 17309286,
#   'gender': 'M',
#   'anchor_age': 81,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2158-04-26 00:00:00')},
#  {'_id': ObjectId('67c5656824c857f62da55c26'),
#   'subject_id': 17359380,
#   'gender': 'F',
#   'anchor_age': 73,
#   'anchor_year': 2149,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56590'),
#   'subject_id': 17439859,
#   'gender': 'M',
#   'anchor_age': 20,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56993'),
#   'subject_id': 17472354,
#   'gender': 'F',
#   'anchor_age': 58,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56af9'),
#   'subject_id': 17483123,
#   'gender': 'F',
#   'anchor_age': 78,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56baf'),
#   'subject_id': 17489585,
#   'gender': 'F',
#   'anchor_age': 76,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56e51'),
#   'subject_id': 17512239,
#   'gender': 'F',
#   'anchor_age': 76,
#   'anchor_year': 2153,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da56ecf'),
#   'subject_id': 17516272,
#   'gender': 'M',
#   'anchor_age': 37,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da57137'),
#   'subject_id': 17536969,
#   'gender': 'F',
#   'anchor_age': 66,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da575ca'),
#   'subject_id': 17577231,
#   'gender': 'M',
#   'anchor_age': 81,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da57710'),
#   'subject_id': 17588958,
#   'gender': 'M',
#   'anchor_age': 37,
#   'anchor_year': 2147,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656824c857f62da57a83'),
#   'subject_id': 17618022,
#   'gender': 'M',
#   'anchor_age': 88,
#   'anchor_year': 2148,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2157-07-03 00:00:00')},
#  {'_id': ObjectId('67c5656824c857f62da58c20'),
#   'subject_id': 17765398,
#   'gender': 'F',
#   'anchor_age': 47,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5a823'),
#   'subject_id': 17999883,
#   'gender': 'F',
#   'anchor_age': 51,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5a944'),
#   'subject_id': 18009231,
#   'gender': 'F',
#   'anchor_age': 63,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5a988'),
#   'subject_id': 18011384,
#   'gender': 'F',
#   'anchor_age': 85,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5b7c8'),
#   'subject_id': 18133146,
#   'gender': 'M',
#   'anchor_age': 73,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-06-09 00:00:00')},
#  {'_id': ObjectId('67c5656924c857f62da5c215'),
#   'subject_id': 18224048,
#   'gender': 'F',
#   'anchor_age': 58,
#   'anchor_year': 2152,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5c6a4'),
#   'subject_id': 18264239,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656924c857f62da5c7f5'),
#   'subject_id': 18275312,
#   'gender': 'M',
#   'anchor_age': 81,
#   'anchor_year': 2153,
#   'anchor_year_group': '2014 - 2016',
#   'dod': Timestamp('2158-05-18 00:00:00')},
#  {'_id': ObjectId('67c5656a24c857f62da5cf8e'),
#   'subject_id': 18339582,
#   'gender': 'M',
#   'anchor_age': 21,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5d2a0'),
#   'subject_id': 18367623,
#   'gender': 'M',
#   'anchor_age': 43,
#   'anchor_year': 2145,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5d310'),
#   'subject_id': 18371155,
#   'gender': 'F',
#   'anchor_age': 60,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2161-02-24 00:00:00')},
#  {'_id': ObjectId('67c5656a24c857f62da5e412'),
#   'subject_id': 18519417,
#   'gender': 'M',
#   'anchor_age': 55,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-09-20 00:00:00')},
#  {'_id': ObjectId('67c5656a24c857f62da5e525'),
#   'subject_id': 18528770,
#   'gender': 'F',
#   'anchor_age': 71,
#   'anchor_year': 2154,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5eabb'),
#   'subject_id': 18574721,
#   'gender': 'M',
#   'anchor_age': 57,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5f51a'),
#   'subject_id': 18664295,
#   'gender': 'F',
#   'anchor_age': 66,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5f584'),
#   'subject_id': 18667723,
#   'gender': 'F',
#   'anchor_age': 84,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da5fa4c'),
#   'subject_id': 18708396,
#   'gender': 'F',
#   'anchor_age': 63,
#   'anchor_year': 2146,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2158-10-24 00:00:00')},
#  {'_id': ObjectId('67c5656a24c857f62da5fae2'),
#   'subject_id': 18712944,
#   'gender': 'M',
#   'anchor_age': 91,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': Timestamp('2155-05-04 00:00:00')},
#  {'_id': ObjectId('67c5656a24c857f62da5fb20'),
#   'subject_id': 18715035,
#   'gender': 'F',
#   'anchor_age': 49,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da60388'),
#   'subject_id': 18785642,
#   'gender': 'F',
#   'anchor_age': 68,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da60413'),
#   'subject_id': 18790180,
#   'gender': 'F',
#   'anchor_age': 57,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656a24c857f62da6071a'),
#   'subject_id': 18816555,
#   'gender': 'F',
#   'anchor_age': 43,
#   'anchor_year': 2155,
#   'anchor_year_group': '2014 - 2016',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656b24c857f62da60a5e'),
#   'subject_id': 18845673,
#   'gender': 'M',
#   'anchor_age': 42,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656b24c857f62da60e59'),
#   'subject_id': 18879099,
#   'gender': 'M',
#   'anchor_age': 48,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656b24c857f62da62585'),
#   'subject_id': 19073526,
#   'gender': 'M',
#   'anchor_age': 80,
#   'anchor_year': 2150,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-05-30 00:00:00')},
#  {'_id': ObjectId('67c5656b24c857f62da628e8'),
#   'subject_id': 19102334,
#   'gender': 'F',
#   'anchor_age': 67,
#   'anchor_year': 2150,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da64810'),
#   'subject_id': 19368299,
#   'gender': 'F',
#   'anchor_age': 76,
#   'anchor_year': 2155,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da64e6f'),
#   'subject_id': 19422002,
#   'gender': 'F',
#   'anchor_age': 22,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da651b7'),
#   'subject_id': 19451054,
#   'gender': 'M',
#   'anchor_age': 53,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da6541f'),
#   'subject_id': 19470526,
#   'gender': 'M',
#   'anchor_age': 46,
#   'anchor_year': 2153,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da65f01'),
#   'subject_id': 19562159,
#   'gender': 'F',
#   'anchor_age': 81,
#   'anchor_year': 2155,
#   'anchor_year_group': '2017 - 2019',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da667fa'),
#   'subject_id': 19638442,
#   'gender': 'F',
#   'anchor_age': 47,
#   'anchor_year': 2151,
#   'anchor_year_group': '2008 - 2010',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da66bdf'),
#   'subject_id': 19672997,
#   'gender': 'F',
#   'anchor_age': 66,
#   'anchor_year': 2155,
#   'anchor_year_group': '2011 - 2013',
#   'dod': Timestamp('2155-05-02 00:00:00')},
#  {'_id': ObjectId('67c5656c24c857f62da685ba'),
#   'subject_id': 19895627,
#   'gender': 'F',
#   'anchor_age': 53,
#   'anchor_year': 2154,
#   'anchor_year_group': '2011 - 2013',
#   'dod': NaT},
#  {'_id': ObjectId('67c5656c24c857f62da68a8a'),
#   'subject_id': 19936109,
#   'gender': 'F',
#   'anchor_age': 80,
#   'anchor_year': 2154,
#   'anchor_year_group': '2008 - 2010',
#   'dod': Timestamp('2155-11-05 00:00:00')}]

# %%
def clean_value(val):
    if isinstance(val, pd.Timestamp):
        return val.to_pydatetime() if pd.notnull(val) else None
    elif isinstance(val, pd.NaT.__class__):
        return None
    return val
df_clean = df_patients.applymap(clean_value)
# Out:
# C:\Users\Harishankar\AppData\Local\Temp\ipykernel_23616\3545497895.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_clean = df_patients.applymap(clean_value)

# %%
records = df_patients.to_dict('records')  
collection = db["patients"]
if records: 
    collection.insert_many(records)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 4
#       2 collection = db["patients"]
#       3 if records:
# ----> 4     collection.insert_many(records)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1896, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1882 """Execute an operation with consecutive retries if possible
#    1883
#    1884 Returns func()'s return value on success. On error retries the same
#    (...)
#    1893 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1894 """
#    1895 with self._tmp_session(session) as s:
# -> 1896     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1782, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1777 # Ensure that the options supports retry_writes and there is a valid session not in
#    1778 # transaction, otherwise, we will not support retry behavior for this txn.
#    1779 retryable = bool(
#    1780     retryable and self.options.retry_writes and session and not session.in_transaction
#    1781 )
# -> 1782 return self._retry_internal(
#    1783     func=func,
#    1784     session=session,
#    1785     bulk=bulk,
#    1786     operation=operation,
#    1787     retryable=retryable,
#    1788     operation_id=operation_id,
#    1789 )
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\mongo_client.py:2687, in _ClientConnectionRetryable._write(self)
#    2685             self._check_last_error()
#    2686             self._retryable = False
# -> 2687         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2688 except PyMongoError as exc:
#    2689     if not self._retryable:
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\synchronous\bulk.py:461, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     453     result = bwc.conn.command(  # type: ignore[misc]
#     454         bwc.db_name,
#     455         batched_cmd,  # type: ignore[arg-type]
#    (...)
#     458         client=client,  # type: ignore[arg-type]
#     459     )
#     460 else:
# --> 461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
#     462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\message.py:699, in _BulkWriteContext.batch_command(self, cmd, docs)
#     695 def batch_command(
#     696     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]]
#     697 ) -> tuple[int, Union[bytes, dict[str, Any]], list[Mapping[str, Any]]]:
#     698     namespace = self.db_name + ".$cmd"
# --> 699     request_id, msg, to_send = _do_batched_op_msg(
#     700         namespace, self.op_type, cmd, docs, self.codec, self
#     701     )
#     702     if not to_send:
#     703         raise InvalidOperation("cannot do an empty bulk write")
#
# File ~\miniconda3\envs\py310\lib\site-packages\pymongo\message.py:926, in _do_batched_op_msg(namespace, operation, command, docs, opts, ctx)
#     924 if ctx.conn.compression_context:
#     925     return _batched_op_msg_compressed(operation, command, docs, ack, opts, ctx)
# --> 926 return _batched_op_msg(operation, command, docs, ack, opts, ctx)
#
# File nattype.pyx:54, in pandas._libs.tslibs.nattype._make_error_func.f()
#
# ValueError: NaTType does not support utcoffset

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'recommender_system')

# %%
# Query all hadm_ids at once using $in
diagnoses_cursor = collection_diagnoses_icd.find({"hadm_id": {"$in": unique_hadm_ids}})
procedures_cursor = collection_procedures_icd.find({"hadm_id": {"$in": unique_hadm_ids}})

# Convert to lists and DataFrames
df_diagnoses = pd.DataFrame(list(diagnoses_cursor))
df_procedures = pd.DataFrame(list(procedures_cursor))

# %%
procedures_cursor = collection_procedures_icd.find({"hadm_id": {"$in": unique_hadm_ids}})
len(list(procedures_cursor))
# Out:
# 510

# %%
records = df_diagnoses.to_dict('records')  
collection = db["procedures_icd"]
if records: 
    collection.insert_many(records)

# %%
records = df_procedures.to_dict('records')  
collection = db["diagnoses_icd"]
if records: 
    collection.insert_many(records)

# %%
df_procedures
# Out:
#                           _id  subject_id   hadm_id  seq_num  chartdate  \
# 0    67c5a8ce60999f4df0732382    10188106  28288574        1 2155-05-10
# 1    67c5a8ce60999f4df0732383    10188106  28288574        2 2155-05-24
# 2    67c5a8ce60999f4df0732384    10188106  28288574        3 2155-05-24
# 3    67c5a8ce60999f4df0732863    10207914  21364683        1 2155-03-27
# 4    67c5a8ce60999f4df0732864    10207914  21364683        2 2155-03-27
# ..                        ...         ...       ...      ...        ...
# 505  67c5a8f460999f4df07d17bb    19936109  24673093        2 2155-03-16
# 506  67c5a8f460999f4df07d17bc    19936109  24673093        3 2155-03-16
# 507  67c5a8f460999f4df07d17bd    19936109  24673093        4 2155-03-16
# 508  67c5a8f460999f4df07d17be    19936109  24673093        5 2155-03-16
# 509  67c5a8f460999f4df07d17bf    19936109  24673093        6 2155-03-16
#
#     icd_code  icd_version
# 0       2309            9
# 1       4836            9
# 2       4516            9
# 3       8103            9
# 4        353            9
# ..       ...          ...
# 505     3772            9
# 506     9671            9
# 507     9604            9
# 508     9962            9
# 509     8872            9
#
# [510 rows x 7 columns]

# %%
df_diagnoses[df_diagnoses['hadm_id']==28335657]
# Out:
#                         _id  subject_id   hadm_id  seq_num icd_code  \
# 0  67c4cbcb44a7421d69772f32    10556566  28335657        1     5609
# 1  67c4cbcb44a7421d69772f33    10556566  28335657        2     7885
# 2  67c4cbcb44a7421d69772f34    10556566  28335657        3     7840
# 3  67c4cbcb44a7421d69772f35    10556566  28335657        4     7821
# 4  67c4cbcb44a7421d69772f36    10556566  28335657        5    27651
# 5  67c4cbcb44a7421d69772f37    10556566  28335657        6     4019
# 6  67c4cbcb44a7421d69772f38    10556566  28335657        7    53081
# 7  67c4cbcb44a7421d69772f39    10556566  28335657        8      311
# 8  67c4cbcb44a7421d69772f3a    10556566  28335657        9    49390
# 9  67c4cbcb44a7421d69772f3b    10556566  28335657       10    V4572
#
#    icd_version
# 0            9
# 1            9
# 2            9
# 3            9
# 4            9
# 5            9
# 6            9
# 7            9
# 8            9
# 9            9
